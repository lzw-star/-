# %% [markdown]
# # CMAPSS  - remaining life cycles

# %% [markdown]
# # Dataset

# %%
import pandas as pd

# !pip install gdown

# Downloading and unzipping the dataset
# !gdown --id 1uNIreOQ1GWxIu_Aw-YWLT-xobcSWV2Kj -O /content/dataset.zip
# !unzip -q /content/dataset.zip -d /content/dataset
# !rm /content/dataset.zip
# Out:
# ...
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1uNIreOQ1GWxIu_Aw-YWLT-xobcSWV2Kj
# To: /content/dataset.zip
# 100% 1.38M/1.38M [00:00<00:00, 12.6MB/s]

# %% [markdown]
# loading dataset

# %%
import pandas as pd
train_df = pd.read_csv('/content/dataset/train_FD001.csv', header=None)
test_df = pd.read_csv('/content/dataset/test_FD001.csv', header=None)
rul_df = pd.read_csv('/content/dataset/RUL_FD001.csv', header=None)

columns = ['rows', 'engine_number', 'time_in_cycles'] + [f'op_setting_{i}' for i in range(1, 4)] + [f'sensor_{i}' for i in range(1, 22)]
train_df.columns = columns
test_df.columns = columns[:3] + [f'op_setting_{i}' for i in range(1, 4)] + [f'sensor_{i}' for i in range(1, 22)]

train_df = train_df.iloc[1:].reset_index(drop=True)
test_df = test_df.iloc[1:].reset_index(drop=True)

# %%
train_df
# Out:
#           rows engine_number time_in_cycles op_setting_1 op_setting_2  \
# 0          0.0             1              1      -0.0007      -0.0004
# 1          1.0             1              2       0.0019      -0.0003
# 2          2.0             1              3      -0.0043       0.0003
# 3          3.0             1              4       0.0007          0.0
# 4          4.0             1              5      -0.0019      -0.0002
# ...        ...           ...            ...          ...          ...
# 20626  20626.0           100            196      -0.0004      -0.0003
# 20627  20627.0           100            197      -0.0016      -0.0005
# 20628  20628.0           100            198       0.0004          0.0
# 20629  20629.0           100            199      -0.0011       0.0003
# 20630  20630.0           100            200      -0.0032      -0.0005
#
#       op_setting_3 sensor_1 sensor_2 sensor_3 sensor_4  ... sensor_12  \
# ...

# %%
test_df
# Out:
#           rows engine_number time_in_cycles op_setting_1 op_setting_2  \
# 0          0.0             1              1       0.0023       0.0003
# 1          1.0             1              2      -0.0027      -0.0003
# 2          2.0             1              3       0.0003       0.0001
# 3          3.0             1              4       0.0042          0.0
# 4          4.0             1              5       0.0014          0.0
# ...        ...           ...            ...          ...          ...
# 13091  13091.0           100            194       0.0049          0.0
# 13092  13092.0           100            195      -0.0011      -0.0001
# 13093  13093.0           100            196      -0.0006      -0.0003
# 13094  13094.0           100            197      -0.0038       0.0001
# 13095  13095.0           100            198       0.0013       0.0003
#
#       op_setting_3 sensor_1 sensor_2 sensor_3 sensor_4  ... sensor_12  \
# ...

# %% [markdown]
# Data selection

# %%
# we remove the specified columns
columns_to_remove = ['rows', 'op_setting_3', 'sensor_1', 'sensor_5', 'sensor_10', 'sensor_16', 'sensor_19']
train_df.drop(columns=columns_to_remove, inplace=True)
test_df.drop(columns=columns_to_remove, inplace=True)

# %%
train_df
# Out:
#       engine_number time_in_cycles op_setting_1 op_setting_2 sensor_2  \
# 0                 1              1      -0.0007      -0.0004   641.82
# 1                 1              2       0.0019      -0.0003   642.15
# 2                 1              3      -0.0043       0.0003   642.35
# 3                 1              4       0.0007          0.0   642.35
# 4                 1              5      -0.0019      -0.0002   642.37
# ...             ...            ...          ...          ...      ...
# 20626           100            196      -0.0004      -0.0003   643.49
# 20627           100            197      -0.0016      -0.0005   643.54
# 20628           100            198       0.0004          0.0   643.42
# 20629           100            199      -0.0011       0.0003   643.23
# 20630           100            200      -0.0032      -0.0005   643.85
#
#       sensor_3 sensor_4 sensor_6 sensor_7 sensor_8 sensor_9 sensor_11  \
# ...

# %% [markdown]
# Reading from original code - note : you have to set in in your repo it is not already in our colab link!

# %%
import pandas as pd

# 读取 CSV 文件
test_data = pd.read_csv("/content/dataset/test_FD001.csv")
true_rul = pd.read_csv("/content/dataset/RUL_FD001.csv")
train_data = pd.read_csv("/content/dataset/train_FD001.csv")

# 保存为 TXT 文件，使用空格分隔
test_data.to_csv("/content/dataset/test_FD001.txt", sep=" ", index=False, header=False)
true_rul.to_csv("/content/dataset/RUL_FD001.txt", sep=" ", index=False, header=False)
train_data.to_csv("/content/dataset/train_FD001.txt", sep=" ", index=False, header=False)

print("CSV 文件已成功转换为 TXT 文件！")
# Out:
# CSV 文件已成功转换为 TXT 文件！

# %%
test_data = pd.read_csv("/content/dataset/test_FD001.txt", sep = "\s+", header = None)
true_rul = pd.read_csv("/content/dataset/RUL_FD001.txt", sep = '\s+', header = None)
train_data = pd.read_csv("/content/dataset/train_FD001.txt", sep = "\s+", header = None)

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

test_data = pd.read_csv("/content/dataset/test_FD001.txt", sep = "\s+", header = None)
train_data = pd.read_csv("/content/dataset/train_FD001.txt", sep = "\s+", header = None)

import pandas as pd
test_df = pd.read_csv('/content/dataset/test_FD001.csv', header=None)
train_df = pd.read_csv('/content/dataset/train_FD001.csv', header=None)

columns = ['rows', 'engine_number', 'time_in_cycles'] + [f'op_setting_{i}' for i in range(1, 4)] + [f'sensor_{i}' for i in range(1, 22)]
test_df.columns = columns

test_df = test_df.iloc[0:].reset_index(drop=True)

test_df = test_df.drop(index=0).reset_index(drop=True)






train_df.columns = columns

train_df = train_df.iloc[0:].reset_index(drop=True)

train_df = train_df.drop(index=0).reset_index(drop=True)

# %%
engine_time_df = test_df[['engine_number', 'time_in_cycles']].copy()
columns_to_be_dropped1 = [0, 1, 4, 5, 9, 14, 20, 23]

columns_to_be_dropped = ['engine_number',	'time_in_cycles','rows', 'op_setting_3', 'sensor_1', 'sensor_5', 'sensor_10', 'sensor_16', 'sensor_19']

test_data_dropped = test_data.drop(columns=columns_to_be_dropped1)
test_df_dropped = test_df.drop(columns=columns_to_be_dropped)

scaler = MinMaxScaler()

test_data_scaled = scaler.fit_transform(test_data_dropped)
test_df_scaled = scaler.fit_transform(test_df_dropped.astype(float))


test_data_scaled_df = pd.DataFrame(test_data_scaled, columns=test_data_dropped.columns)
test_df_scaled_df = pd.DataFrame(test_df_scaled, columns=test_df_dropped.columns)

test_df_scaled_df.to_csv('/content/dataset/test_FD001_normalized.csv', header=False, index=False)



engine_time_df = test_df[['engine_number', 'time_in_cycles']].copy()
columns_to_be_dropped1 = [0, 1, 4, 5, 9, 14, 20, 23]

columns_to_be_dropped = ['engine_number',	'time_in_cycles','rows', 'op_setting_3', 'sensor_1', 'sensor_5', 'sensor_10', 'sensor_16', 'sensor_19']

test_data_dropped = test_data.drop(columns=columns_to_be_dropped1)
test_df_dropped = test_df.drop(columns=columns_to_be_dropped)

scaler = MinMaxScaler()

test_data_scaled = scaler.fit_transform(test_data_dropped)
test_df_scaled = scaler.fit_transform(test_df_dropped.astype(float))


test_data_scaled_df = pd.DataFrame(test_data_scaled, columns=test_data_dropped.columns)
test_df_scaled_df = pd.DataFrame(test_df_scaled, columns=test_df_dropped.columns)

test_df_scaled_df.to_csv('/content/dataset/test_FD001_normalized.csv', header=False, index=False)

# %%
test_data_scaled_df
# Out:
#              2        3    6         7         8    10   11        12  \
# 0      0.000000  0.65625  0.0  0.596215  0.421968  0.0  1.0  0.608871
# 1      0.003311  0.34375  0.0  0.182965  0.504025  0.0  1.0  0.800403
# 2      0.006623  0.53125  0.0  0.419558  0.464814  0.0  1.0  0.651210
# 3      0.009934  0.77500  0.0  0.413249  0.391587  0.0  1.0  0.643145
# 4      0.013245  0.60000  0.0  0.435331  0.471306  0.0  1.0  0.661290
# ...         ...      ...  ...       ...       ...  ...  ...       ...
# 13091  0.639073  0.81875  0.0  0.665615  0.789665  0.0  1.0  0.510081
# 13092  0.642384  0.44375  0.0  0.659306  0.692028  0.0  1.0  0.471774
# 13093  0.645695  0.47500  0.0  0.728707  0.626071  0.0  1.0  0.435484
# 13094  0.649007  0.27500  0.0  0.671924  0.673851  0.0  1.0  0.502016
# 13095  0.652318  0.59375  0.0  0.574132  0.846014  0.0  1.0  0.322581
#
#              13   15        16        17        18        19   21     22   24  \
# ...

# %% [markdown]
# Data Normalization

# %%
test_df_scaled_df
# Out:
#        op_setting_1  op_setting_2  sensor_2  sensor_3  sensor_4  sensor_6  \
# 0           0.65625      0.692308  0.596215  0.421968  0.282214       1.0
# 1           0.34375      0.230769  0.182965  0.504025  0.225240       1.0
# 2           0.53125      0.538462  0.419558  0.464814  0.346130       1.0
# 3           0.77500      0.461538  0.413249  0.391587  0.449867       1.0
# 4           0.60000      0.461538  0.435331  0.471306  0.357974       1.0
# ...             ...           ...       ...       ...       ...       ...
# 13091       0.81875      0.461538  0.665615  0.789665  0.641209       1.0
# 13092       0.44375      0.384615  0.659306  0.692028  0.769042       1.0
# 13093       0.47500      0.230769  0.728707  0.626071  0.458036       1.0
# 13094       0.27500      0.538462  0.671924  0.673851  0.714111       1.0
# 13095       0.59375      0.692308  0.574132  0.846014  0.829079       1.0
#
#        sensor_7  sensor_8  sensor_9  sensor_11  sensor_12  sensor_13  \
# ...

# %%
engine_time_df = train_df[['engine_number', 'time_in_cycles']].copy()
columns_to_be_dropped1 = [0, 1, 4, 5, 9, 14, 20, 23]

columns_to_be_dropped = ['engine_number',	'time_in_cycles','rows', 'op_setting_3', 'sensor_1', 'sensor_5', 'sensor_10', 'sensor_16', 'sensor_19']

train_data_dropped = train_data.drop(columns=columns_to_be_dropped1)
train_df_dropped = train_df.drop(columns=columns_to_be_dropped)

scaler = MinMaxScaler()

train_data_scaled = scaler.fit_transform(train_data_dropped)
train_df_scaled = scaler.fit_transform(train_df_dropped.astype(float))


train_data_scaled_df = pd.DataFrame(train_data_scaled, columns=train_data_dropped.columns)
trian_df_scaled_df = pd.DataFrame(train_df_scaled, columns=train_df_dropped.columns)




engine_time_df = train_df[['engine_number', 'time_in_cycles']].copy()
columns_to_be_dropped1 = [0, 1, 4, 5, 9, 14, 20, 23]

columns_to_be_dropped = ['engine_number',	'time_in_cycles','rows', 'op_setting_3', 'sensor_1', 'sensor_5', 'sensor_10', 'sensor_16', 'sensor_19']

train_data_dropped = train_data.drop(columns=columns_to_be_dropped1)
train_df_dropped = train_df.drop(columns=columns_to_be_dropped)

scaler = MinMaxScaler()

train_data_scaled = scaler.fit_transform(train_data_dropped)
train_df_scaled = scaler.fit_transform(train_df_dropped.astype(float))


train_data_scaled_df = pd.DataFrame(train_data_scaled, columns=train_data_dropped.columns)
train_df_scaled_df = pd.DataFrame(train_df_scaled, columns=train_df_dropped.columns)

train_df_scaled_df.to_csv('/content/dataset/train_FD001_normalized.csv', header=False, index=False)

# %%
engine_time_df
# Out:
#       engine_number time_in_cycles
# 0                 1              1
# 1                 1              2
# 2                 1              3
# 3                 1              4
# 4                 1              5
# ...             ...            ...
# 20626           100            196
# 20627           100            197
# 20628           100            198
# 20629           100            199
# 20630           100            200
#
# [20631 rows x 2 columns]

# %%
train_data_scaled_df
# Out:
#              2         3    6         7         8    10   11        12  \
# 0      0.000000  0.459770  0.0  0.183735  0.406802  0.0  1.0  0.726248
# 1      0.002770  0.609195  0.0  0.283133  0.453019  0.0  1.0  0.628019
# 2      0.005540  0.252874  0.0  0.343373  0.369523  0.0  1.0  0.710145
# 3      0.008310  0.540230  0.0  0.343373  0.256159  0.0  1.0  0.740741
# 4      0.011080  0.390805  0.0  0.349398  0.257467  0.0  1.0  0.668277
# ...         ...       ...  ...       ...       ...  ...  ...       ...
# 20626  0.540166  0.477011  0.0  0.686747  0.587312  0.0  1.0  0.254428
# 20627  0.542936  0.408046  0.0  0.701807  0.729453  0.0  1.0  0.162641
# 20628  0.545706  0.522989  0.0  0.665663  0.684979  0.0  1.0  0.175523
# 20629  0.548476  0.436782  0.0  0.608434  0.746021  0.0  1.0  0.133655
# 20630  0.551247  0.316092  0.0  0.795181  0.639634  0.0  1.0  0.151369
#
#              13   15        16        17        18        19   21        22  \
# ...

# %%
train_df_scaled_df
# Out:
#        op_setting_1  op_setting_2  sensor_2  sensor_3  sensor_4  sensor_6  \
# 0          0.459770      0.166667  0.183735  0.406802  0.309757       1.0
# 1          0.609195      0.250000  0.283133  0.453019  0.352633       1.0
# 2          0.252874      0.750000  0.343373  0.369523  0.370527       1.0
# 3          0.540230      0.500000  0.343373  0.256159  0.331195       1.0
# 4          0.390805      0.333333  0.349398  0.257467  0.404625       1.0
# ...             ...           ...       ...       ...       ...       ...
# 20626      0.477011      0.250000  0.686747  0.587312  0.782917       1.0
# 20627      0.408046      0.083333  0.701807  0.729453  0.866475       1.0
# 20628      0.522989      0.500000  0.665663  0.684979  0.775321       1.0
# 20629      0.436782      0.750000  0.608434  0.746021  0.747468       1.0
# 20630      0.316092      0.083333  0.795181  0.639634  0.842167       1.0
#
#        sensor_7  sensor_8  sensor_9  sensor_11  sensor_12  sensor_13  \
# ...

# %% [markdown]
# ### Normalization

# %%
from sklearn.preprocessing import MinMaxScaler

features_to_normalize = train_df.columns[2:]
print()
train_df[features_to_normalize] = train_df[features_to_normalize].apply(pd.to_numeric, errors='coerce')
test_df[features_to_normalize] = test_df[features_to_normalize].apply(pd.to_numeric, errors='coerce')

# we use the min-max-scaler in sklearn lib
scaler = MinMaxScaler()
train_df[features_to_normalize] = scaler.fit_transform(train_df[features_to_normalize])
test_df[features_to_normalize] = scaler.transform(test_df[features_to_normalize])

# %%
train_df = pd.read_csv('/content/dataset/train_FD001.txt', sep="\s+", header=None)

columns = ['engine_number', 'time_in_cycles'] + [f'op_setting_{i}' for i in range(1, 4)] + [f'sensor_{i}' for i in range(1, 22)]
train_df.columns = columns

max_cycles = train_df.groupby('engine_number')['time_in_cycles'].max().reset_index()

sorted_max_cycles = max_cycles.sort_values(by='engine_number').reset_index(drop=True)

print(sorted_max_cycles)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-6ebd069a2f9d> in <cell line: 4>()
#       2
#       3 columns = ['engine_number', 'time_in_cycles'] + [f'op_setting_{i}' for i in range(1, 4)] + [f'sensor_{i}' for i in range(1, 22)]
# ----> 4 train_df.columns = columns
#       5
#       6 max_cycles = train_df.groupby('engine_number')['time_in_cycles'].max().reset_index()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    6311         try:
#    6312             object.__getattribute__(self, name)
# -> 6313             return object.__setattr__(self, name, value)
#    6314         except AttributeError:
#    6315             pass
#
# properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
# ...

# %%
train_df['time_in_cycles'] = pd.to_numeric(train_df['time_in_cycles'], errors='coerce')

rul = pd.DataFrame(train_df.groupby('engine_number')['time_in_cycles'].max()).reset_index()
rul.columns = ['engine_number', 'max_time_in_cycles']
train_df = train_df.merge(rul, on='engine_number')

train_df['RUL'] = train_df['max_time_in_cycles'] - train_df['time_in_cycles']
train_df.drop('max_time_in_cycles', axis=1, inplace=True)

train_df['RUL'] = train_df['RUL'].apply(lambda x: min(x, 130))

time_window = 50
train_df['label'] = train_df['RUL'].apply(lambda x: 1 if x > time_window else 0)

# %%
train_df

# %%
train_rul = pd.DataFrame(train_df.groupby('engine_number')['time_in_cycles'].max()).reset_index()
train_rul

# %%
import pandas as pd
train_df = pd.read_csv('/content/dataset/train_FD001.csv', header=None)
test_df = pd.read_csv('/content/dataset/test_FD001.csv', header=None)
test_rul_df = pd.read_csv('/content/dataset/RUL_FD001.csv', header=None)

columns = ['rows', 'engine_number', 'time_in_cycles'] + [f'op_setting_{i}' for i in range(1, 4)] + [f'sensor_{i}' for i in range(1, 22)]
train_df.columns = columns
test_df.columns = columns

test_df.columns = columns

test_df = test_df.iloc[0:].reset_index(drop=True)

test_df = test_df.drop(index=0).reset_index(drop=True)
train_df.columns = columns

train_df = train_df.iloc[0:].reset_index(drop=True)

train_df = train_df.drop(index=0).reset_index(drop=True)

columns_to_remove = ['rows', 'op_setting_3', 'sensor_1', 'sensor_5', 'sensor_10', 'sensor_16', 'sensor_19']
train_df.drop(columns=columns_to_remove, inplace=True)
test_df.drop(columns=columns_to_remove, inplace=True)



from sklearn.preprocessing import MinMaxScaler

features_to_normalize = train_df.columns[2:]

train_df[features_to_normalize] = train_df[features_to_normalize].apply(pd.to_numeric, errors='coerce')
test_df[features_to_normalize] = test_df[features_to_normalize].apply(pd.to_numeric, errors='coerce')

scaler = MinMaxScaler()
train_df[features_to_normalize] = scaler.fit_transform(train_df[features_to_normalize])
test_df[features_to_normalize] = scaler.transform(test_df[features_to_normalize])


train_df['time_in_cycles'] = pd.to_numeric(train_df['time_in_cycles'], errors='coerce')

rul = pd.DataFrame(train_df.groupby('engine_number')['time_in_cycles'].max()).reset_index()
rul.columns = ['engine_number', 'max_time_in_cycles']
train_df = train_df.merge(rul, on='engine_number')

train_df['RUL'] = train_df['max_time_in_cycles'] - train_df['time_in_cycles']
train_df.drop('max_time_in_cycles', axis=1, inplace=True)

train_df['RUL'] = train_df['RUL'].apply(lambda x: min(x, 130))

time_window = 50
train_df['label'] = train_df['RUL'].apply(lambda x: 1 if x > time_window else 0)

train_rul = pd.DataFrame(train_df.groupby('engine_number')['time_in_cycles'].max()).reset_index()
train_rul

# %% [markdown]
# ### Our data now has label

# %%
train_df

# %%
train_df.to_csv('/content/dataset/train_FD001_complete.csv', header=False, index=False)

# %%
train_df['RUL'][0:192]

# %%
# Plotting the first 192 RUL values
import numpy as np
import matplotlib.pyplot as plt
x_range = np.linspace(1, 193, 192)
plt.plot(x_range, train_df['RUL'][0:192])
plt.xlabel('Index')
plt.ylabel('RUL')
plt.title('RUL over Index Range')
plt.show()

# %%
#for regression
def create_time_windows(df, window_size, step):
    X, y = [], []
    for engine in df['engine_number'].unique():
        engine_df = df[df['engine_number'] == engine]
        for start in range(0, len(engine_df) - window_size + 1, step):
            end = start + window_size
            X.append(engine_df.iloc[start:end, 2:-2].values)
            y.append(engine_df.iloc[end - 1, -2])
    return np.array(X), np.array(y)

window_size = 30
X_train_r, y_train_r = create_time_windows(train_df, window_size, 1)

print(X_train_r.shape, y_train_r.shape)

# %%
X_train_r[0,1,:]

# %%
y_train_r

# %%
# for classification
def create_time_windows(df, window_size, step):
    X, y = [], []
    for engine in df['engine_number'].unique():
        engine_df = df[df['engine_number'] == engine]
        for start in range(0, len(engine_df) - window_size + 1, step):
            end = start + window_size
            X.append(engine_df.iloc[start:end, 2:-2].values)
            y.append(engine_df.iloc[end - 1, -1])  # thats for classification!
    return np.array(X), np.array(y)

window_size = 30
X_train_c, y_train_c = create_time_windows(train_df, window_size, 1)

print(X_train_c.shape, y_train_c.shape)

# %% [markdown]
# Now we apply the preprocessing for the test set

# %% [markdown]
# ### Complete train preprocessing

# %% [markdown]
# Here is the complete trainig dataset initialization

# %%
import pandas as pd
train_df = pd.read_csv('/content/dataset/train_FD001.csv', header=None)
test_df = pd.read_csv('/content/dataset/test_FD001.csv', header=None)
test_rul_df = pd.read_csv('/content/dataset/RUL_FD001.csv', header=None)

columns = ['rows', 'engine_number', 'time_in_cycles'] + [f'op_setting_{i}' for i in range(1, 4)] + [f'sensor_{i}' for i in range(1, 22)]
train_df.columns = columns
test_df.columns = columns

test_df.columns = columns

test_df = test_df.iloc[0:].reset_index(drop=True)

test_df = test_df.drop(index=0).reset_index(drop=True)
train_df.columns = columns

train_df = train_df.iloc[0:].reset_index(drop=True)

train_df = train_df.drop(index=0).reset_index(drop=True)

columns_to_remove = ['rows', 'op_setting_3', 'sensor_1', 'sensor_5', 'sensor_10', 'sensor_16', 'sensor_19']
train_df.drop(columns=columns_to_remove, inplace=True)
test_df.drop(columns=columns_to_remove, inplace=True)



from sklearn.preprocessing import MinMaxScaler

features_to_normalize = train_df.columns[2:]

train_df[features_to_normalize] = train_df[features_to_normalize].apply(pd.to_numeric, errors='coerce')
test_df[features_to_normalize] = test_df[features_to_normalize].apply(pd.to_numeric, errors='coerce')

scaler = MinMaxScaler()
train_df[features_to_normalize] = scaler.fit_transform(train_df[features_to_normalize])
test_df[features_to_normalize] = scaler.transform(test_df[features_to_normalize])


train_df['time_in_cycles'] = pd.to_numeric(train_df['time_in_cycles'], errors='coerce')

rul = pd.DataFrame(train_df.groupby('engine_number')['time_in_cycles'].max()).reset_index()
rul.columns = ['engine_number', 'max_time_in_cycles']
train_df = train_df.merge(rul, on='engine_number')

train_df['RUL'] = train_df['max_time_in_cycles'] - train_df['time_in_cycles']
train_df.drop('max_time_in_cycles', axis=1, inplace=True)

train_df['RUL'] = train_df['RUL'].apply(lambda x: min(x, 130))

time_window = 50
train_df['label'] = train_df['RUL'].apply(lambda x: 1 if x > time_window else 0)

train_rul = pd.DataFrame(train_df.groupby('engine_number')['time_in_cycles'].max()).reset_index()
#for regression
def create_time_windows(df, window_size, step):
    X, y = [], []
    for engine in df['engine_number'].unique():
        engine_df = df[df['engine_number'] == engine]
        for start in range(0, len(engine_df) - window_size + 1, step):
            end = start + window_size
            X.append(engine_df.iloc[start:end, 2:-2].values)
            y.append(engine_df.iloc[end - 1, -2])
    return np.array(X), np.array(y)

window_size = 30
X_train_r, y_train_r = create_time_windows(train_df, window_size, 1)

print(X_train_r.shape, y_train_r.shape)

# %% [markdown]
# ### Preprocessing test

# %%
import pandas as pd
test_df = pd.read_csv('/content/dataset/test_FD001.csv', header=None)
test_rul_df = pd.read_csv('/content/dataset/RUL_FD001.csv', header=None)

columns = ['rows', 'engine_number', 'time_in_cycles'] + [f'op_setting_{i}' for i in range(1, 4)] + [f'sensor_{i}' for i in range(1, 22)]
test_df.columns = columns


test_df  = test_df.iloc[0:].reset_index(drop=True)

test_df  = test_df.drop(index=0).reset_index(drop=True)


columns_to_remove = ['rows', 'op_setting_3', 'sensor_1', 'sensor_5', 'sensor_10', 'sensor_16', 'sensor_19']
test_df.drop(columns=columns_to_remove, inplace=True)



from sklearn.preprocessing import MinMaxScaler

features_to_normalize = train_df.columns[2:]

test_df[features_to_normalize] = test_df[features_to_normalize].apply(pd.to_numeric, errors='coerce')

scaler = MinMaxScaler()
test_df[features_to_normalize]  = scaler.fit_transform(test_df[features_to_normalize])


test_df['time_in_cycles'] = pd.to_numeric(test_df['time_in_cycles'], errors='coerce')


rul = pd.DataFrame(test_df.groupby('engine_number')['time_in_cycles'].max()).reset_index()
rul.columns = ['engine_number', 'max_time_in_cycles']
test_df = test_df.merge(rul, on='engine_number')

test_df['RUL'] = test_df['max_time_in_cycles'] - test_df['time_in_cycles']
test_df.drop('max_time_in_cycles', axis=1, inplace=True)


test_rul_df.columns = ['unused', 'RUL', 'unit_number']
test_rul_df.drop(columns=['unused'], inplace=True)
test_rul_df['RUL'] = pd.to_numeric(test_rul_df['RUL'], errors='coerce')
test_rul_df

rul = rul.merge(test_rul_df[['unit_number', 'RUL']], left_on='engine_number', right_on='unit_number', how='left')
test_df = test_df.merge(rul[['engine_number', 'max_time_in_cycles', 'RUL']], on='engine_number')

test_df['RUL'] = test_df['RUL_x'] + test_df['RUL_y']
test_df[0:60]

# %% [markdown]
# #### implementing all window

# %%
import pandas as pd
test_df = pd.read_csv('/content/dataset/test_FD001.csv', header=None)
test_rul_df = pd.read_csv('/content/dataset/RUL_FD001.csv', header=None)

columns = ['rows', 'engine_number', 'time_in_cycles'] + [f'op_setting_{i}' for i in range(1, 4)] + [f'sensor_{i}' for i in range(1, 22)]
test_df.columns = columns


test_df  = test_df.iloc[0:].reset_index(drop=True)

test_df  = test_df.drop(index=0).reset_index(drop=True)


columns_to_remove = ['rows', 'op_setting_3', 'sensor_1', 'sensor_5', 'sensor_10', 'sensor_16', 'sensor_19']
test_df.drop(columns=columns_to_remove, inplace=True)



from sklearn.preprocessing import MinMaxScaler

features_to_normalize = train_df.columns[2:]

test_df[features_to_normalize] = test_df[features_to_normalize].apply(pd.to_numeric, errors='coerce')

scaler = MinMaxScaler()
test_df[features_to_normalize]  = scaler.fit_transform(test_df[features_to_normalize])


test_df['time_in_cycles'] = pd.to_numeric(test_df['time_in_cycles'], errors='coerce')


rul = pd.DataFrame(test_df.groupby('engine_number')['time_in_cycles'].max()).reset_index()
rul.columns = ['engine_number', 'max_time_in_cycles']
test_df = test_df.merge(rul, on='engine_number')

test_df['RUL'] = test_df['max_time_in_cycles'] - test_df['time_in_cycles']
test_df.drop('max_time_in_cycles', axis=1, inplace=True)


test_rul_df.columns = ['unused', 'RUL', 'unit_number']
test_rul_df.drop(columns=['unused'], inplace=True)
test_rul_df['RUL'] = pd.to_numeric(test_rul_df['RUL'], errors='coerce')
test_rul_df

rul = rul.merge(test_rul_df[['unit_number', 'RUL']], left_on='engine_number', right_on='unit_number', how='left')
test_df = test_df.merge(rul[['engine_number', 'max_time_in_cycles', 'RUL']], on='engine_number')

test_df['RUL'] = test_df['RUL_x'] + test_df['RUL_y']
test_df['RUL'] = test_df['RUL'].apply(lambda x: min(x, 130))
test_df.drop(columns=[ 'RUL_x', 'max_time_in_cycles', 'RUL_y'], inplace=True)




time_window = 50
test_df['label'] = test_df['RUL'].apply(lambda x: 1 if x > time_window else 0)

test_rul = pd.DataFrame(test_df.groupby('engine_number')['time_in_cycles'].max()).reset_index()
#for regression
def create_time_windows(df, window_size, step):
    X, y = [], []
    for engine in df['engine_number'].unique():
        engine_df = df[df['engine_number'] == engine]
        print(len(engine_df))
        for start in range(0, len(engine_df) - window_size + 1, step):
            end = start + window_size
            X.append(engine_df.iloc[start:end, 2:-2].values)
            y.append(engine_df.iloc[end - 1, -2])
    return np.array(X), np.array(y)

window_size = 30
X_test_r, y_test_r = create_time_windows(test_df, window_size, 1)

print(X_test_r.shape, y_test_r.shape)

# %%
y_test_r[0:200]

# %% [markdown]
# #### implementing last window for test

# %%
import pandas as pd
train_df = pd.read_csv('/content/dataset/train_FD001.csv', header=None)
test_df = pd.read_csv('/content/dataset/test_FD001.csv', header=None)
test_rul_df = pd.read_csv('/content/dataset/RUL_FD001.csv', header=None)

columns = ['rows', 'engine_number', 'time_in_cycles'] + [f'op_setting_{i}' for i in range(1, 4)] + [f'sensor_{i}' for i in range(1, 22)]
train_df.columns = columns
test_df.columns = columns

test_df.columns = columns

test_df = test_df.iloc[0:].reset_index(drop=True)

test_df = test_df.drop(index=0).reset_index(drop=True)
train_df.columns = columns

train_df = train_df.iloc[0:].reset_index(drop=True)

train_df = train_df.drop(index=0).reset_index(drop=True)

columns_to_remove = ['rows', 'op_setting_3', 'sensor_1', 'sensor_5', 'sensor_10', 'sensor_16', 'sensor_19']
train_df.drop(columns=columns_to_remove, inplace=True)
test_df.drop(columns=columns_to_remove, inplace=True)



from sklearn.preprocessing import MinMaxScaler

features_to_normalize = train_df.columns[2:]

train_df[features_to_normalize] = train_df[features_to_normalize].apply(pd.to_numeric, errors='coerce')
test_df[features_to_normalize] = test_df[features_to_normalize].apply(pd.to_numeric, errors='coerce')

scaler = MinMaxScaler()
train_df[features_to_normalize] = scaler.fit_transform(train_df[features_to_normalize])
test_df[features_to_normalize] = scaler.transform(test_df[features_to_normalize])



test_df['time_in_cycles'] = pd.to_numeric(test_df['time_in_cycles'], errors='coerce')


rul = pd.DataFrame(test_df.groupby('engine_number')['time_in_cycles'].max()).reset_index()
rul.columns = ['engine_number', 'max_time_in_cycles']
test_df = test_df.merge(rul, on='engine_number')

test_df['RUL'] = test_df['max_time_in_cycles'] - test_df['time_in_cycles']
test_df.drop('max_time_in_cycles', axis=1, inplace=True)


test_rul_df.columns = ['unused', 'RUL', 'unit_number']
test_rul_df.drop(columns=['unused'], inplace=True)
test_rul_df['RUL'] = pd.to_numeric(test_rul_df['RUL'], errors='coerce')
test_rul_df

rul = rul.merge(test_rul_df[['unit_number', 'RUL']], left_on='engine_number', right_on='unit_number', how='left')
test_df = test_df.merge(rul[['engine_number', 'max_time_in_cycles', 'RUL']], on='engine_number')

test_df['RUL'] = test_df['RUL_x'] + test_df['RUL_y']
test_df['RUL'] = test_df['RUL'].apply(lambda x: min(x, 130))
test_df.drop(columns=[ 'RUL_x', 'max_time_in_cycles', 'RUL_y'], inplace=True)




time_window = 50
test_df['label'] = test_df['RUL'].apply(lambda x: 1 if x > time_window else 0)

test_rul = pd.DataFrame(test_df.groupby('engine_number')['time_in_cycles'].max()).reset_index()
#for regression last window
def create_time_windows(df, window_size, step):
    X, y = [], []
    for engine in df['engine_number'].unique():
        engine_df = df[df['engine_number'] == engine]
        for start in range(len(engine_df) - window_size , len(engine_df) - window_size + 1, step):
            end = start + window_size
            X.append(engine_df.iloc[start:end, 2:-2].values)
            y.append(engine_df.iloc[end - 1, -2])
    return np.array(X), np.array(y)

window_size = 30
X_test_r, y_test_r = create_time_windows(test_df, window_size, 1)

print(X_test_r.shape, y_test_r.shape)

# %%
y_test_r

# %%
max_cycle_test = test_df.groupby('engine_number')['time_in_cycles'].max().reset_index()
max_cycle_test.columns = ['engine_number', 'max_time_in_cycles']

test_rul_df.columns = ['unused', 'RUL', 'unit_number']
test_rul_df.drop(columns=['unused'], inplace=True)
test_rul_df['RUL'] = pd.to_numeric(test_rul_df['RUL'], errors='coerce')

max_cycle_test = max_cycle_test.merge(test_rul_df[['unit_number', 'RUL']], left_on='engine_number', right_on='unit_number', how='left')

print("Max cycle test DataFrame after merging with RUL:")
print(max_cycle_test.head())

test_df = test_df.merge(max_cycle_test[['engine_number', 'max_time_in_cycles', 'RUL']], on='engine_number')

test_df['RUL'] = pd.to_numeric(test_df['RUL'])
test_df['max_time_in_cycles'] = pd.to_numeric(test_df['max_time_in_cycles'], errors='coerce')
test_df['time_in_cycles'] = pd.to_numeric(test_df['time_in_cycles'], errors='coerce')

test_df['RUL'] = test_df['max_time_in_cycles'] + test_df['RUL'] - test_df['time_in_cycles']

# %%
train_df['RUL'] = train_df['RUL'].apply(lambda x: min(x, 130))

time_window = 50
train_df['label'] = train_df['RUL'].apply(lambda x: 1 if x > time_window else 0)

train_rul = pd.DataFrame(train_df.groupby('engine_number')['time_in_cycles'].max()).reset_index()
def create_time_windows(df, window_size, step):
    X, y = [], []
    for engine in df['engine_number'].unique():
        engine_df = df[df['engine_number'] == engine]
        for start in range(0, len(engine_df) - window_size + 1, step):
            end = start + window_size
            X.append(engine_df.iloc[start:end, 2:-2].values)
            y.append(engine_df.iloc[end - 1, -2])
    return np.array(X), np.array(y)

window_size = 30
X_train_r, y_train_r = create_time_windows(train_df, window_size, 1)

print(X_train_r.shape, y_train_r.shape)

# %%
train_df['time_in_cycles'] = pd.to_numeric(train_df['time_in_cycles'], errors='coerce')

rul = pd.DataFrame(train_df.groupby('engine_number')['time_in_cycles'].max()).reset_index()
rul.columns = ['engine_number', 'max_time_in_cycles']
train_df = train_df.merge(rul, on='engine_number')

train_df['RUL'] = train_df['max_time_in_cycles'] - train_df['time_in_cycles']
train_df.drop('max_time_in_cycles', axis=1, inplace=True)

train_df['RUL'] = train_df['RUL'].apply(lambda x: min(x, 130))

time_window = 50
train_df['label'] = train_df['RUL'].apply(lambda x: 1 if x > time_window else 0)

train_rul = pd.DataFrame(train_df.groupby('engine_number')['time_in_cycles'].max()).reset_index()
def create_time_windows(df, window_size, step):
    X, y = [], []
    for engine in df['engine_number'].unique():
        engine_df = df[df['engine_number'] == engine]
        for start in range(0, len(engine_df) - window_size + 1, step):
            end = start + window_size
            X.append(engine_df.iloc[start:end, 2:-2].values)
            y.append(engine_df.iloc[end - 1, -2])
    return np.array(X), np.array(y)

window_size = 30
X_train_r, y_train_r = create_time_windows(train_df, window_size, 1)

print(X_train_r.shape, y_train_r.shape)

# %%
def create_time_windows(df, window_size, step):
    X, y = [], []
    for engine in df['engine_number'].unique():
        engine_df = df[df['engine_number'] == engine]
        for start in range(0, len(engine_df) - window_size + 1, step):
            end = start + window_size
            X.append(engine_df.iloc[start:end, 2:-2].values)
            y.append(engine_df.iloc[end - 1, -2])
    return np.array(X), np.array(y)

window_size = 30
X_train_r, y_train_r = create_time_windows(train_df, window_size, 1)

print(X_train_r.shape, y_train_r.shape)

# %% [markdown]
# ### Complete test and train preprocessing for last window of test

# %%
import pandas as pd
train_df = pd.read_csv('/content/dataset/train_FD001.csv', header=None)
test_df = pd.read_csv('/content/dataset/test_FD001.csv', header=None)
test_rul_df = pd.read_csv('/content/dataset/RUL_FD001.csv', header=None)

columns = ['rows', 'engine_number', 'time_in_cycles'] + [f'op_setting_{i}' for i in range(1, 4)] + [f'sensor_{i}' for i in range(1, 22)]
train_df.columns = columns
test_df.columns = columns

test_df.columns = columns

test_df = test_df.iloc[0:].reset_index(drop=True)

test_df = test_df.drop(index=0).reset_index(drop=True)
train_df.columns = columns

train_df = train_df.iloc[0:].reset_index(drop=True)

train_df = train_df.drop(index=0).reset_index(drop=True)

columns_to_remove = ['rows', 'op_setting_3', 'sensor_1', 'sensor_5', 'sensor_10', 'sensor_16', 'sensor_19']
train_df.drop(columns=columns_to_remove, inplace=True)
test_df.drop(columns=columns_to_remove, inplace=True)



from sklearn.preprocessing import MinMaxScaler

features_to_normalize = train_df.columns[2:]

train_df[features_to_normalize] = train_df[features_to_normalize].apply(pd.to_numeric, errors='coerce')
test_df[features_to_normalize] = test_df[features_to_normalize].apply(pd.to_numeric, errors='coerce')

scaler = MinMaxScaler()
train_df[features_to_normalize] = scaler.fit_transform(train_df[features_to_normalize])
test_df[features_to_normalize] = scaler.transform(test_df[features_to_normalize])


## ---------------------Testing--------------Last Window-----------------------

test_df['time_in_cycles'] = pd.to_numeric(test_df['time_in_cycles'], errors='coerce')


rul = pd.DataFrame(test_df.groupby('engine_number')['time_in_cycles'].max()).reset_index()
rul.columns = ['engine_number', 'max_time_in_cycles']
test_df = test_df.merge(rul, on='engine_number')

test_df['RUL'] = test_df['max_time_in_cycles'] - test_df['time_in_cycles']
test_df.drop('max_time_in_cycles', axis=1, inplace=True)


test_rul_df.columns = ['unused', 'RUL', 'unit_number']
test_rul_df.drop(columns=['unused'], inplace=True)
test_rul_df['RUL'] = pd.to_numeric(test_rul_df['RUL'], errors='coerce')
test_rul_df

rul = rul.merge(test_rul_df[['unit_number', 'RUL']], left_on='engine_number', right_on='unit_number', how='left')
test_df = test_df.merge(rul[['engine_number', 'max_time_in_cycles', 'RUL']], on='engine_number')

test_df['RUL'] = test_df['RUL_x'] + test_df['RUL_y']
test_df['RUL'] = test_df['RUL'].apply(lambda x: min(x, 130))
test_df.drop(columns=[ 'RUL_x', 'max_time_in_cycles', 'RUL_y'], inplace=True)




time_window = 50
test_df['label'] = test_df['RUL'].apply(lambda x: 1 if x > time_window else 0)

test_rul = pd.DataFrame(test_df.groupby('engine_number')['time_in_cycles'].max()).reset_index()
#for regression last window
def create_time_windows(df, window_size, step):
    X, y = [], []
    for engine in df['engine_number'].unique():
        engine_df = df[df['engine_number'] == engine]
        for start in range(len(engine_df) - window_size , len(engine_df) - window_size + 1, step):
            end = start + window_size
            X.append(engine_df.iloc[start:end, 2:-2].values)
            y.append(engine_df.iloc[end - 1, -2])
    return np.array(X), np.array(y)

window_size = 30
X_test_r, y_test_r = create_time_windows(test_df, window_size, 1)

print(X_test_r.shape, y_test_r.shape)

#--------------Training-----------------------------

train_df['time_in_cycles'] = pd.to_numeric(train_df['time_in_cycles'], errors='coerce')

rul = pd.DataFrame(train_df.groupby('engine_number')['time_in_cycles'].max()).reset_index()
rul.columns = ['engine_number', 'max_time_in_cycles']
train_df = train_df.merge(rul, on='engine_number')

train_df['RUL'] = train_df['max_time_in_cycles'] - train_df['time_in_cycles']
train_df.drop('max_time_in_cycles', axis=1, inplace=True)

train_df['RUL'] = train_df['RUL'].apply(lambda x: min(x, 130))

time_window = 50
train_df['label'] = train_df['RUL'].apply(lambda x: 1 if x > time_window else 0)

train_rul = pd.DataFrame(train_df.groupby('engine_number')['time_in_cycles'].max()).reset_index()
#for regression
def create_time_windows(df, window_size, step):
    X, y = [], []
    for engine in df['engine_number'].unique():
        engine_df = df[df['engine_number'] == engine]
        for start in range(0, len(engine_df) - window_size + 1, step):
            end = start + window_size
            X.append(engine_df.iloc[start:end, 2:-2].values)
            y.append(engine_df.iloc[end - 1, -2])
    return np.array(X), np.array(y)

window_size = 30
X_train_r, y_train_r = create_time_windows(train_df, window_size, 1)

print(X_train_r.shape, y_train_r.shape)

# %% [markdown]
# ### Complete test and train preprocessing for All window of test

# %%
import pandas as pd
train_df = pd.read_csv('/content/dataset/train_FD001.csv', header=None)
test_df = pd.read_csv('/content/dataset/test_FD001.csv', header=None)
test_rul_df = pd.read_csv('/content/dataset/RUL_FD001.csv', header=None)

columns = ['rows', 'engine_number', 'time_in_cycles'] + [f'op_setting_{i}' for i in range(1, 4)] + [f'sensor_{i}' for i in range(1, 22)]
train_df.columns = columns
test_df.columns = columns

test_df.columns = columns

test_df = test_df.iloc[0:].reset_index(drop=True)

test_df = test_df.drop(index=0).reset_index(drop=True)
train_df.columns = columns

train_df = train_df.iloc[0:].reset_index(drop=True)

train_df = train_df.drop(index=0).reset_index(drop=True)

columns_to_remove = ['rows', 'op_setting_3', 'sensor_1', 'sensor_5', 'sensor_10', 'sensor_16', 'sensor_19']
train_df.drop(columns=columns_to_remove, inplace=True)
test_df.drop(columns=columns_to_remove, inplace=True)



from sklearn.preprocessing import MinMaxScaler

features_to_normalize = train_df.columns[2:]

train_df[features_to_normalize] = train_df[features_to_normalize].apply(pd.to_numeric, errors='coerce')
test_df[features_to_normalize] = test_df[features_to_normalize].apply(pd.to_numeric, errors='coerce')

scaler = MinMaxScaler()
train_df[features_to_normalize] = scaler.fit_transform(train_df[features_to_normalize])
test_df[features_to_normalize] = scaler.transform(test_df[features_to_normalize])


## ---------------------Testing--------------Last Window-----------------------

test_df['time_in_cycles'] = pd.to_numeric(test_df['time_in_cycles'], errors='coerce')


rul = pd.DataFrame(test_df.groupby('engine_number')['time_in_cycles'].max()).reset_index()
rul.columns = ['engine_number', 'max_time_in_cycles']
test_df = test_df.merge(rul, on='engine_number')

test_df['RUL'] = test_df['max_time_in_cycles'] - test_df['time_in_cycles']
test_df.drop('max_time_in_cycles', axis=1, inplace=True)


test_rul_df.columns = ['unused', 'RUL', 'unit_number']
test_rul_df.drop(columns=['unused'], inplace=True)
test_rul_df['RUL'] = pd.to_numeric(test_rul_df['RUL'], errors='coerce')
test_rul_df

rul = rul.merge(test_rul_df[['unit_number', 'RUL']], left_on='engine_number', right_on='unit_number', how='left')
test_df = test_df.merge(rul[['engine_number', 'max_time_in_cycles', 'RUL']], on='engine_number')

test_df['RUL'] = test_df['RUL_x'] + test_df['RUL_y']
test_df['RUL'] = test_df['RUL'].apply(lambda x: min(x, 130))
test_df.drop(columns=[ 'RUL_x', 'max_time_in_cycles', 'RUL_y'], inplace=True)




time_window = 50
test_df['label'] = test_df['RUL'].apply(lambda x: 1 if x > time_window else 0)

test_rul = pd.DataFrame(test_df.groupby('engine_number')['time_in_cycles'].max()).reset_index()
#for regression last window

def create_time_windows(df, window_size, step):
    X, y = [], []
    for engine in df['engine_number'].unique():
        engine_df = df[df['engine_number'] == engine]
        print(len(engine_df))
        for start in range(0, len(engine_df) - window_size + 1, step):
            end = start + window_size
            X.append(engine_df.iloc[start:end, 2:-2].values)
            y.append(engine_df.iloc[end - 1, -2])
    return np.array(X), np.array(y)

window_size = 30
X_test_r, y_test_r = create_time_windows(test_df, window_size, 1)

print(X_test_r.shape, y_test_r.shape)

#--------------Training-----------------------------

train_df['time_in_cycles'] = pd.to_numeric(train_df['time_in_cycles'], errors='coerce')

rul = pd.DataFrame(train_df.groupby('engine_number')['time_in_cycles'].max()).reset_index()
rul.columns = ['engine_number', 'max_time_in_cycles']
train_df = train_df.merge(rul, on='engine_number')

train_df['RUL'] = train_df['max_time_in_cycles'] - train_df['time_in_cycles']
train_df.drop('max_time_in_cycles', axis=1, inplace=True)

train_df['RUL'] = train_df['RUL'].apply(lambda x: min(x, 130))

time_window = 50
train_df['label'] = train_df['RUL'].apply(lambda x: 1 if x > time_window else 0)

train_rul = pd.DataFrame(train_df.groupby('engine_number')['time_in_cycles'].max()).reset_index()
#for regression
def create_time_windows(df, window_size, step):
    X, y = [], []
    for engine in df['engine_number'].unique():
        engine_df = df[df['engine_number'] == engine]
        for start in range(0, len(engine_df) - window_size + 1, step):
            end = start + window_size
            X.append(engine_df.iloc[start:end, 2:-2].values)
            y.append(engine_df.iloc[end - 1, -2])
    return np.array(X), np.array(y)

window_size = 30
X_train_r, y_train_r = create_time_windows(train_df, window_size, 1)

print(X_train_r.shape, y_train_r.shape)

# %% [markdown]
# # Regression

# %% [markdown]
# ### Data preprocessing for regression

# %%
import pandas as pd
import numpy as np

train_df = pd.read_csv('/content/dataset/train_FD001.csv', header=None)
test_df = pd.read_csv('/content/dataset/test_FD001.csv', header=None)
test_rul_df = pd.read_csv('/content/dataset/RUL_FD001.csv', header=None)

columns = ['rows', 'engine_number', 'time_in_cycles'] + [f'op_setting_{i}' for i in range(1, 4)] + [f'sensor_{i}' for i in range(1, 22)]
train_df.columns = columns
test_df.columns = columns

test_df.columns = columns

test_df = test_df.iloc[0:].reset_index(drop=True)

test_df = test_df.drop(index=0).reset_index(drop=True)
train_df.columns = columns

train_df = train_df.iloc[0:].reset_index(drop=True)

train_df = train_df.drop(index=0).reset_index(drop=True)

columns_to_remove = ['rows', 'op_setting_3', 'sensor_1', 'sensor_5', 'sensor_10', 'sensor_16', 'sensor_19']
train_df.drop(columns=columns_to_remove, inplace=True)
test_df.drop(columns=columns_to_remove, inplace=True)



from sklearn.preprocessing import MinMaxScaler

features_to_normalize = train_df.columns[2:]

train_df[features_to_normalize] = train_df[features_to_normalize].apply(pd.to_numeric, errors='coerce')
test_df[features_to_normalize] = test_df[features_to_normalize].apply(pd.to_numeric, errors='coerce')

scaler = MinMaxScaler()
train_df[features_to_normalize] = scaler.fit_transform(train_df[features_to_normalize])
test_df[features_to_normalize] = scaler.transform(test_df[features_to_normalize])


## ---------------------Testing--------------------------

test_df['time_in_cycles'] = pd.to_numeric(test_df['time_in_cycles'], errors='coerce')


rul = pd.DataFrame(test_df.groupby('engine_number')['time_in_cycles'].max()).reset_index()
rul.columns = ['engine_number', 'max_time_in_cycles']
test_df = test_df.merge(rul, on='engine_number')

test_df['RUL'] = test_df['max_time_in_cycles'] - test_df['time_in_cycles']
test_df.drop('max_time_in_cycles', axis=1, inplace=True)


test_rul_df.columns = ['unused', 'RUL', 'unit_number']
test_rul_df.drop(columns=['unused'], inplace=True)
test_rul_df['RUL'] = pd.to_numeric(test_rul_df['RUL'], errors='coerce')
k=test_rul_df

rul = rul.merge(test_rul_df[['unit_number', 'RUL']], left_on='engine_number', right_on='unit_number', how='left')
test_df = test_df.merge(rul[['engine_number', 'max_time_in_cycles', 'RUL']], on='engine_number')

test_df['RUL'] = test_df['RUL_x'] + test_df['RUL_y']

test_df['RUL'] = test_df['RUL'].apply(lambda x: min(x, 130))
test_df.drop(columns=[ 'RUL_x', 'max_time_in_cycles', 'RUL_y'], inplace=True)

#------Last Window-----------------------
time_window = 50
test_df['label'] = test_df['RUL'].apply(lambda x: 1 if x > time_window else 0)

test_rul = pd.DataFrame(test_df.groupby('engine_number')['time_in_cycles'].max()).reset_index()
#for regression last window
def create_time_windows(df, window_size, step):
    X, y = [], []
    for engine in df['engine_number'].unique():
        engine_df = df[df['engine_number'] == engine]
        for start in range(len(engine_df) - window_size , len(engine_df) - window_size + 1, step):
            end = start + window_size
            X.append(engine_df.iloc[start:end, 2:-2].values)
            y.append(engine_df.iloc[end - 1, -2]) # thats for classification
    return np.array(X), np.array(y)

window_size = 30
processed_test_data_L, true_rul_L = create_time_windows(test_df, window_size, 1)


print("Processed test data shape for last window: ", processed_test_data_L.shape)
print("True RUL Labels shape for last window: ", true_rul_L.shape)

#------for whole window-----------------------

def create_time_windows(df, window_size, step):
    X, y = [], []
    for engine in df['engine_number'].unique():
        engine_df = df[df['engine_number'] == engine]
        for start in range(0, len(engine_df) - window_size + 1, step):
            end = start + window_size
            X.append(engine_df.iloc[start:end, 2:-2].values)
            y.append(engine_df.iloc[end - 1, -2]) #for regression
    return np.array(X), np.array(y)

window_size = 30
processed_test_data, true_rul = create_time_windows(test_df, window_size, 1)


print("Processed test data shape: ", processed_test_data.shape)
print("True RUL Labels shape: ", true_rul.shape)

#--------------Training---------------only labeling is different in test--------------

train_df['time_in_cycles'] = pd.to_numeric(train_df['time_in_cycles'], errors='coerce')

rul = pd.DataFrame(train_df.groupby('engine_number')['time_in_cycles'].max()).reset_index()
rul.columns = ['engine_number', 'max_time_in_cycles']
train_df = train_df.merge(rul, on='engine_number')

train_df['RUL'] = train_df['max_time_in_cycles'] - train_df['time_in_cycles']
train_df.drop('max_time_in_cycles', axis=1, inplace=True)

train_df['RUL'] = train_df['RUL'].apply(lambda x: min(x, 130))

time_window = 50
train_df['label'] = train_df['RUL'].apply(lambda x: 1 if x > time_window else 0)

train_rul = pd.DataFrame(train_df.groupby('engine_number')['time_in_cycles'].max()).reset_index()
#for regression
def create_time_windows(df, window_size, step):
    X, y = [], []
    for engine in df['engine_number'].unique():
        engine_df = df[df['engine_number'] == engine]
        for start in range(0, len(engine_df) - window_size + 1, step):
            end = start + window_size
            X.append(engine_df.iloc[start:end, 2:-2].values)
            y.append(engine_df.iloc[end - 1, -2])
    return np.array(X), np.array(y)

window_size = 30
processed_train_data, processed_train_targets = create_time_windows(train_df, window_size, 1)


print("Processed training data shape: ", processed_train_data.shape)
print("Processed training targets labels shape: ", processed_train_targets.shape)

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, LSTM, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.models import load_model
from sklearn.metrics import mean_absolute_error
import matplotlib.pyplot as plt

processed_train_data, processed_val_data, processed_train_targets, processed_val_targets = train_test_split(processed_train_data,
                                                                                                            processed_train_targets,
                                                                                                            test_size = 0.2,
                                                                                                            random_state = 83)


processed_train_data=processed_train_data.astype('float32')
processed_val_data=processed_val_data.astype('float32')
processed_train_targets=processed_train_targets.astype('float32')
processed_val_targets=processed_val_targets.astype('float32')



print("Processed train data shape: ", processed_train_data.shape)
print("Processed validation data shape: ", processed_val_data.shape)
print("Processed train targets shape: ", processed_train_targets.shape)
print("Processed validation targets shape: ", processed_val_targets.shape)

# %% [markdown]
# ## Regression with early stop

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, LSTM, Dense, Flatten,Dropout
import tensorflow as tf
# Checkking if GPU is available
if tf.config.list_physical_devices('GPU'):
    device_name = tf.test.gpu_device_name()
    print(f"Using GPU: {device_name}")
else:
    print("No GPU found. Using CPU.")

def create_cnn_lstm_model(input_shape):
    model = Sequential()
    model.add(Conv1D(filters=32, kernel_size=5, activation='relu', input_shape=input_shape))
    model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling1D(pool_size=3))
    model.add(LSTM(50, return_sequences=True, activation='tanh'))
    model.add(Dropout(0.2))
    model.add(LSTM(50, return_sequences=False, activation='tanh'))
    model.add(Dropout(0.2))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(1, activation='linear'))
    return model

input_shape = (processed_train_data.shape[1], processed_train_data.shape[2])
model = create_cnn_lstm_model(input_shape)


from tensorflow.keras.optimizers import Adam,RMSprop
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

model.compile(optimizer=RMSprop(learning_rate=0.001), loss='mean_squared_error', metrics=['mean_absolute_error'])


early_stopping = EarlyStopping(monitor='val_loss', patience=10)
model_checkpoint = ModelCheckpoint('best_model.h5', monitor='val_loss')

history = model.fit(processed_train_data, processed_train_targets, validation_data=(processed_val_data, processed_val_targets), epochs=100, batch_size=200, callbacks=[early_stopping, model_checkpoint])

# %%
def plot_history(history):
    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Train MSE')
    plt.plot(history.history['val_loss'], label='Val MSE')
    plt.title('Model Mean Squared Error')
    plt.xlabel('Epoch')
    plt.ylabel('Mean Squared Error')
    plt.legend(loc='upper right')

    plt.subplot(1, 2, 2)
    plt.plot(history.history['mean_absolute_error'], label='Train MAE')
    plt.plot(history.history['val_mean_absolute_error'], label='Val MAE')
    plt.title('Model Mean Absolute Error')
    plt.xlabel('Epoch')
    plt.ylabel('Mean Absolute Error')
    plt.legend(loc='upper right')

    plt.tight_layout()
    plt.show()

# %%
plot_history(history)

# %% [markdown]
# testing for  whole windows

# %%
rul_pred = model.predict(processed_test_data).reshape(-1)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np

def compute_regression_metrics(true_rul,rul_pred):
    def mean_absolute_percentage_error(y_true, y_pred):
        y_true, y_pred = np.array(y_true), np.array(y_pred)
        return np.mean(np.abs((y_true - y_pred) / y_true)) * 100


    # Calculate errors
    rmse = np.sqrt(mean_squared_error(true_rul, rul_pred))
    mse = mean_squared_error(true_rul, rul_pred)
    mae = mean_absolute_error(true_rul, rul_pred)
    mape = mean_absolute_percentage_error(true_rul, rul_pred)

    # Print the errors
    print("RMSE: ", rmse)
    print("MSE: ", mse)
    print("MAE: ", mae)
    print("MAPE: ", mape)

    return rmse,mse,mae,mape

# %%
rmse,mse,mae,mape=compute_regression_metrics(true_rul,rul_pred)
print('regression CNN-LSTM with early stopping')
model_performance = pd.DataFrame({
    'Metric': ['RMSE', 'MSE', 'MAE', 'MAPE'],
    'Value': [rmse, mse, mae, mape]
})

model_performance_styled = model_performance.style.hide(axis='index').background_gradient(cmap='RdYlBu_r').format({'Value': '{:.4f}'})

model_performance_styled

# %% [markdown]
# test result Only for last window

# %%
rul_pred = model.predict(processed_test_data_L).reshape(-1)

# %%
rmse,mse,mae,mape=compute_regression_metrics(true_rul_L,rul_pred)
print('regression CNN-LSTM with early stopping - last window')
model_performance = pd.DataFrame({
    'Metric': ['RMSE', 'MSE', 'MAE', 'MAPE'],
    'Value': [rmse, mse, mae, mape]
})

model_performance_styled = model_performance.style.hide(axis='index').background_gradient(cmap='RdYlBu_r').format({'Value': '{:.4f}'})

model_performance_styled

# %%
true_rul_L

# %%
rul_pred

# %%
import seaborn as sns

plt.style.use('seaborn-white')
plt.rcParams['figure.figsize']=20,5

fig,ax = plt.subplots()
plt.ylabel('RUL')
plt.xlabel('Engine nr')

g = sns.lineplot(x = np.arange(0,100),
                y=true_rul_L,
                color='green',
                label = 'actual',
                ax=ax)

f = sns.lineplot(x = np.arange(0,100),
                y=rul_pred,
                color='steelblue',
                label = 'predictions',
                ax=ax)
ax.legend()

# %%
concat = np.vstack((rul_pred,true_rul_L))
sorted_concat = np.sort(concat, axis=None)

sorted_concat = sorted_concat.reshape(concat.shape)

# %%
k=k['RUL'][1:]
k.to_numpy()
k = k.astype(int)

# %%
import numpy as np
import matplotlib.pyplot as plt

concat = np.vstack((rul_pred,true_rul_L))
sorted_concat = np.sort(concat, axis=None)

sorted_concat = sorted_concat.reshape(concat.shape)

k = k.astype(float)
rul_pred = rul_pred.astype(float)

indices = np.argsort(k.values)
sorted_true_rul = k.values[indices]
sorted_predicted_rul = rul_pred[indices]

plt.figure(figsize=(12, 6))

plt.scatter(range(len(sorted_true_rul)), sorted_true_rul, color='red', label='Actual RUL')
plt.scatter(range(len(sorted_predicted_rul)), sorted_predicted_rul, color='blue', label='Predicted RUL')

for i in range(len(sorted_true_rul)):
    plt.plot([i, i], [sorted_true_rul[i], sorted_predicted_rul[i]], color='gray', linestyle='--')

plt.xlabel('Index')
plt.ylabel('RUL')
plt.title('Actual vs Predicted RUL in asceneding order')
plt.legend()
plt.grid(True)
plt.tight_layout()

plt.show()

# %% [markdown]
# Now lets see the preformance of model without early stopping

# %% [markdown]
# ## Regression without early stopping

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, LSTM, Dense, Flatten,Dropout

def create_cnn_lstm_model(input_shape):
    model = Sequential()
    model.add(Conv1D(filters=32, kernel_size=5, activation='relu', input_shape=input_shape))
    model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling1D(pool_size=3))
    model.add(LSTM(50, return_sequences=True, activation='tanh'))
    model.add(Dropout(0.2))
    model.add(LSTM(50, return_sequences=False, activation='tanh'))
    model.add(Dropout(0.2))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(1, activation='linear'))  # For regression, use linear activation
    return model

input_shape = (processed_train_data.shape[1], processed_train_data.shape[2])
model = create_cnn_lstm_model(input_shape)


from tensorflow.keras.optimizers import Adam,RMSprop
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

model.compile(optimizer=RMSprop(learning_rate=0.001), loss='mean_squared_error', metrics=['mean_absolute_error'])


model_checkpoint = ModelCheckpoint('best_model.h5', monitor='val_loss')

history = model.fit(processed_train_data, processed_train_targets, validation_data=(processed_val_data, processed_val_targets), epochs=100, batch_size=200, callbacks=[ model_checkpoint])

# %%
plot_history(history)

# %% [markdown]
# testing for whole windows

# %%
rul_pred = model.predict(processed_test_data).reshape(-1)

# %%
rmse,mse,mae,mape=compute_regression_metrics(true_rul,rul_pred)
print('regression CNN-LSTM with early stopping')
model_performance = pd.DataFrame({
    'Metric': ['RMSE', 'MSE', 'MAE', 'MAPE'],
    'Value': [rmse, mse, mae, mape]
})

model_performance_styled = model_performance.style.hide(axis='index').background_gradient(cmap='RdYlBu_r').format({'Value': '{:.4f}'})

model_performance_styled

# %% [markdown]
# test result Only for last window

# %%
rul_pred = model.predict(processed_test_data_L).reshape(-1)

# %%
rmse,mse,mae,mape=compute_regression_metrics(true_rul_L,rul_pred)
print('regression CNN-LSTM with early stopping - last window')
model_performance = pd.DataFrame({
    'Metric': ['RMSE', 'MSE', 'MAE', 'MAPE'],
    'Value': [rmse, mse, mae, mape]
})

# Style the DataFrame
model_performance_styled = model_performance.style.hide(axis='index').background_gradient(cmap='RdYlBu_r').format({'Value': '{:.4f}'})

# Display the styled DataFrame
model_performance_styled

# %%
true_rul_L

# %%
rul_pred

# %%
import seaborn as sns

plt.style.use('seaborn-white')
plt.rcParams['figure.figsize']=20,5

fig,ax = plt.subplots()
plt.ylabel('RUL')
plt.xlabel('Engine nr')

g = sns.lineplot(x = np.arange(0,100),
                y=true_rul_L,
                color='green',
                label = 'actual',
                ax=ax)

f = sns.lineplot(x = np.arange(0,100),
                y=rul_pred,
                color='steelblue',
                label = 'predictions',
                ax=ax)
ax.legend()

# %%
import numpy as np
import matplotlib.pyplot as plt

concat = np.vstack((rul_pred,true_rul_L))
sorted_concat = np.sort(concat, axis=None)

sorted_concat = sorted_concat.reshape(concat.shape)

k = k.astype(float)
rul_pred = rul_pred.astype(float)

# Sort the data based on true RUL values
indices = np.argsort(k.values)
sorted_true_rul = k.values[indices]
sorted_predicted_rul = rul_pred[indices]

plt.figure(figsize=(12, 6))

plt.scatter(range(len(sorted_true_rul)), sorted_true_rul, color='red', label='Actual RUL')
plt.scatter(range(len(sorted_predicted_rul)), sorted_predicted_rul, color='blue', label='Predicted RUL')

for i in range(len(sorted_true_rul)):
    plt.plot([i, i], [sorted_true_rul[i], sorted_predicted_rul[i]], color='gray', linestyle='--')

plt.xlabel('Index')
plt.ylabel('RUL')
plt.title('Actual vs Predicted RUL in asceneding order')
plt.legend()
plt.grid(True)
plt.tight_layout()

plt.show()

# %% [markdown]
# ## LSTM for Regression

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, LSTM, Dense, Flatten,Dropout

def r_lstm_model(input_shape):
    model = Sequential()
    model.add(LSTM(128, input_shape=input_shape, return_sequences=True, activation='tanh'))
    model.add(Dropout(0.2))
    model.add(LSTM(64, return_sequences=True, activation='tanh'))
    model.add(Dropout(0.2))
    model.add(LSTM(32, activation='tanh'))
    model.add(Dense(96, activation='relu'))
    model.add(Dense(128, activation='relu'))
    model.add(Dense(1, activation='linear'))
    return model

input_shape = (processed_train_data.shape[1], processed_train_data.shape[2])
model = r_lstm_model(input_shape)


from tensorflow.keras.optimizers import Adam,RMSprop
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

model.compile(optimizer=RMSprop(learning_rate=0.001), loss='mean_squared_error', metrics=['mean_absolute_error'])

early_stopping = EarlyStopping(monitor='val_loss', patience=10)
model_checkpoint = ModelCheckpoint('best_model.h5', monitor='val_loss')

history = model.fit(processed_train_data, processed_train_targets, validation_data=(processed_val_data, processed_val_targets), epochs=100, batch_size=200, callbacks=[early_stopping, model_checkpoint])

# %%
plot_history(history)

# %%
model.summary()

# %% [markdown]
# testing for whole windows

# %%
rul_pred = model.predict(processed_test_data).reshape(-1)

# %%
rmse,mse,mae,mape=compute_regression_metrics(true_rul,rul_pred)
print('regression CNN-LSTM with early stopping')
model_performance = pd.DataFrame({
    'Metric': ['RMSE', 'MSE', 'MAE', 'MAPE'],
    'Value': [rmse, mse, mae, mape]
})

# Style the DataFrame
model_performance_styled = model_performance.style.hide(axis='index').background_gradient(cmap='RdYlBu_r').format({'Value': '{:.4f}'})

# Display the styled DataFrame
model_performance_styled

# %% [markdown]
# test result Only for last window

# %%
rul_pred = model.predict(processed_test_data_L).reshape(-1)

# %%
rmse,mse,mae,mape=compute_regression_metrics(true_rul_L,rul_pred)
print('regression CNN-LSTM with early stopping - last window')
model_performance = pd.DataFrame({
    'Metric': ['RMSE', 'MSE', 'MAE', 'MAPE'],
    'Value': [rmse, mse, mae, mape]
})

model_performance_styled = model_performance.style.hide(axis='index').background_gradient(cmap='RdYlBu_r').format({'Value': '{:.4f}'})

model_performance_styled

# %%
import seaborn as sns

plt.style.use('seaborn-white')
plt.rcParams['figure.figsize']=20,5

fig,ax = plt.subplots()
plt.ylabel('RUL')
plt.xlabel('Engine nr')

g = sns.lineplot(x = np.arange(0,100),
                y=true_rul_L,
                color='green',
                label = 'actual',
                ax=ax)

f = sns.lineplot(x = np.arange(0,100),
                y=rul_pred,
                color='steelblue',
                label = 'predictions',
                ax=ax)
ax.legend()

# %%
import numpy as np
import matplotlib.pyplot as plt

concat = np.vstack((rul_pred,true_rul_L))
sorted_concat = np.sort(concat, axis=None)

sorted_concat = sorted_concat.reshape(concat.shape)

k = k.astype(float)
rul_pred = rul_pred.astype(float)

indices = np.argsort(k.values)
sorted_true_rul = k.values[indices]
sorted_predicted_rul = rul_pred[indices]

plt.figure(figsize=(12, 6))

plt.scatter(range(len(sorted_true_rul)), sorted_true_rul, color='red', label='Actual RUL')
plt.scatter(range(len(sorted_predicted_rul)), sorted_predicted_rul, color='blue', label='Predicted RUL')

for i in range(len(sorted_true_rul)):
    plt.plot([i, i], [sorted_true_rul[i], sorted_predicted_rul[i]], color='gray', linestyle='--')

plt.xlabel('Index')
plt.ylabel('RUL')
plt.title('Actual vs Predicted RUL in asceneding order')
plt.legend()
plt.grid(True)
plt.tight_layout()

plt.show()

# %% [markdown]
# ## CNN model for regression

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, GlobalAveragePooling1D, Dense, Flatten,Dropout

def r_cnn_model(input_shape):
    model = Sequential()
    model.add(Conv1D(256, 7, activation='relu', input_shape=input_shape))
    model.add(Conv1D(96, 7, activation='relu'))
    model.add(Conv1D(32, 7, activation='relu'))
    model.add(GlobalAveragePooling1D())
    model.add(Dense(64, activation='relu'))
    model.add(Dense(128, activation='relu'))
    model.add(Dense(1, activation='linear'))  # For regression, use linear activation
    return model
input_shape = (processed_train_data.shape[1], processed_train_data.shape[2])
model = r_cnn_model(input_shape)



from tensorflow.keras.optimizers import Adam,RMSprop
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

model.compile(optimizer=RMSprop(learning_rate=0.001), loss='mean_squared_error', metrics=['mean_absolute_error'])

early_stopping = EarlyStopping(monitor='val_loss', patience=10)
model_checkpoint = ModelCheckpoint('CNN_regression_model.h5', monitor='val_loss')

history = model.fit(processed_train_data, processed_train_targets, validation_data=(processed_val_data, processed_val_targets), epochs=100, batch_size=200, callbacks=[early_stopping, model_checkpoint])

# %%
model.summary()

# %%
plot_history(history)

# %% [markdown]
# testing for whole windows

# %%
rul_pred = model.predict(processed_test_data).reshape(-1)

# %%
rmse,mse,mae,mape=compute_regression_metrics(true_rul,rul_pred)
print('regression CNN-LSTM with early stopping')
model_performance = pd.DataFrame({
    'Metric': ['RMSE', 'MSE', 'MAE', 'MAPE'],
    'Value': [rmse, mse, mae, mape]
})

model_performance_styled = model_performance.style.hide(axis='index').background_gradient(cmap='RdYlBu_r').format({'Value': '{:.4f}'})

model_performance_styled

# %% [markdown]
# test result Only for last window

# %%
rul_pred = model.predict(processed_test_data_L).reshape(-1)

# %%
rmse,mse,mae,mape=compute_regression_metrics(true_rul_L,rul_pred)
print('regression CNN-LSTM with early stopping - last window')
model_performance = pd.DataFrame({
    'Metric': ['RMSE', 'MSE', 'MAE', 'MAPE'],
    'Value': [rmse, mse, mae, mape]
})

model_performance_styled = model_performance.style.hide(axis='index').background_gradient(cmap='RdYlBu_r').format({'Value': '{:.4f}'})

model_performance_styled

# %%
import seaborn as sns

plt.style.use('seaborn-white')
plt.rcParams['figure.figsize']=20,5

fig,ax = plt.subplots()
plt.ylabel('RUL')
plt.xlabel('Engine nr')

g = sns.lineplot(x = np.arange(0,100),
                y=true_rul_L,
                color='green',
                label = 'actual',
                ax=ax)

f = sns.lineplot(x = np.arange(0,100),
                y=rul_pred,
                color='steelblue',
                label = 'predictions',
                ax=ax)
ax.legend()

# %%
import numpy as np
import matplotlib.pyplot as plt

concat = np.vstack((rul_pred,true_rul_L))
sorted_concat = np.sort(concat, axis=None)

sorted_concat = sorted_concat.reshape(concat.shape)

k = k.astype(float)
rul_pred = rul_pred.astype(float)

indices = np.argsort(k.values)
sorted_true_rul = k.values[indices]
sorted_predicted_rul = rul_pred[indices]

plt.figure(figsize=(12, 6))

plt.scatter(range(len(sorted_true_rul)), sorted_true_rul, color='red', label='Actual RUL')
plt.scatter(range(len(sorted_predicted_rul)), sorted_predicted_rul, color='blue', label='Predicted RUL')

for i in range(len(sorted_true_rul)):
    plt.plot([i, i], [sorted_true_rul[i], sorted_predicted_rul[i]], color='gray', linestyle='--')

plt.xlabel('Index')
plt.ylabel('RUL')
plt.title('Actual vs Predicted RUL in asceneding order')
plt.legend()
plt.grid(True)
plt.tight_layout()

plt.show()

# %% [markdown]
# # Classification

# %% [markdown]
# ### preprocessing data set for classification

# %% [markdown]
# We use this initialization

# %%
import pandas as pd
import numpy as np

train_df = pd.read_csv('/content/dataset/train_FD001.csv', header=None)
test_df = pd.read_csv('/content/dataset/test_FD001.csv', header=None)
test_rul_df = pd.read_csv('/content/dataset/RUL_FD001.csv', header=None)

columns = ['rows', 'engine_number', 'time_in_cycles'] + [f'op_setting_{i}' for i in range(1, 4)] + [f'sensor_{i}' for i in range(1, 22)]
train_df.columns = columns
test_df.columns = columns

test_df.columns = columns

test_df = test_df.iloc[0:].reset_index(drop=True)

test_df = test_df.drop(index=0).reset_index(drop=True)
train_df.columns = columns

train_df = train_df.iloc[0:].reset_index(drop=True)

train_df = train_df.drop(index=0).reset_index(drop=True)

columns_to_remove = ['rows', 'op_setting_3', 'sensor_1', 'sensor_5', 'sensor_10', 'sensor_16', 'sensor_19']
train_df.drop(columns=columns_to_remove, inplace=True)
test_df.drop(columns=columns_to_remove, inplace=True)



from sklearn.preprocessing import MinMaxScaler

features_to_normalize = train_df.columns[2:]

train_df[features_to_normalize] = train_df[features_to_normalize].apply(pd.to_numeric, errors='coerce')
test_df[features_to_normalize] = test_df[features_to_normalize].apply(pd.to_numeric, errors='coerce')

scaler = MinMaxScaler()
train_df[features_to_normalize] = scaler.fit_transform(train_df[features_to_normalize])
test_df[features_to_normalize] = scaler.transform(test_df[features_to_normalize])


## ---------------------Testing--------------------------

test_df['time_in_cycles'] = pd.to_numeric(test_df['time_in_cycles'], errors='coerce')


rul = pd.DataFrame(test_df.groupby('engine_number')['time_in_cycles'].max()).reset_index()
rul.columns = ['engine_number', 'max_time_in_cycles']
test_df = test_df.merge(rul, on='engine_number')

test_df['RUL'] = test_df['max_time_in_cycles'] - test_df['time_in_cycles']
test_df.drop('max_time_in_cycles', axis=1, inplace=True)


test_rul_df.columns = ['unused', 'RUL', 'unit_number']
test_rul_df.drop(columns=['unused'], inplace=True)
test_rul_df['RUL'] = pd.to_numeric(test_rul_df['RUL'], errors='coerce')
test_rul_df

rul = rul.merge(test_rul_df[['unit_number', 'RUL']], left_on='engine_number', right_on='unit_number', how='left')
test_df = test_df.merge(rul[['engine_number', 'max_time_in_cycles', 'RUL']], on='engine_number')

test_df['RUL'] = test_df['RUL_x'] + test_df['RUL_y']
test_df['RUL'] = test_df['RUL'].apply(lambda x: min(x, 130))
test_df.drop(columns=[ 'RUL_x', 'max_time_in_cycles', 'RUL_y'], inplace=True)

#------Last Window-----------------------
time_window = 50
test_df['label'] = test_df['RUL'].apply(lambda x: 1 if x > time_window else 0)

test_rul = pd.DataFrame(test_df.groupby('engine_number')['time_in_cycles'].max()).reset_index()
#for regression last window
def create_time_windows(df, window_size, step):
    X, y = [], []
    for engine in df['engine_number'].unique():
        engine_df = df[df['engine_number'] == engine]
        for start in range(len(engine_df) - window_size , len(engine_df) - window_size + 1, step):
            end = start + window_size
            X.append(engine_df.iloc[start:end, 2:-2].values)
            y.append(engine_df.iloc[end - 1, -1]) # thats for classification
    return np.array(X), np.array(y)

window_size = 30
processed_test_data_L, true_rul_labels_L = create_time_windows(test_df, window_size, 1)


print("Processed test data shape for last window: ", processed_test_data_L.shape)
print("True RUL Labels shape for last window: ", true_rul_labels_L.shape)

#------for whole window-----------------------

def create_time_windows(df, window_size, step):
    X, y = [], []
    for engine in df['engine_number'].unique():
        engine_df = df[df['engine_number'] == engine]
        for start in range(0, len(engine_df) - window_size + 1, step):
            end = start + window_size
            X.append(engine_df.iloc[start:end, 2:-2].values)
            y.append(engine_df.iloc[end - 1, -1])
    return np.array(X), np.array(y)

window_size = 30
processed_test_data2, true_rul_labels2 = create_time_windows(test_df, window_size, 1)


print("Processed test data shape: ", processed_test_data2.shape)
print("True RUL Labels shape: ", true_rul_labels2.shape)

#--------------Training---------------only labeling is different in test--------------

train_df['time_in_cycles'] = pd.to_numeric(train_df['time_in_cycles'], errors='coerce')

rul = pd.DataFrame(train_df.groupby('engine_number')['time_in_cycles'].max()).reset_index()
rul.columns = ['engine_number', 'max_time_in_cycles']
train_df = train_df.merge(rul, on='engine_number')

train_df['RUL'] = train_df['max_time_in_cycles'] - train_df['time_in_cycles']
train_df.drop('max_time_in_cycles', axis=1, inplace=True)

train_df['RUL'] = train_df['RUL'].apply(lambda x: min(x, 130))

time_window = 50
train_df['label'] = train_df['RUL'].apply(lambda x: 1 if x > time_window else 0)

train_rul = pd.DataFrame(train_df.groupby('engine_number')['time_in_cycles'].max()).reset_index()
#for regression
def create_time_windows(df, window_size, step):
    X, y = [], []
    for engine in df['engine_number'].unique():
        engine_df = df[df['engine_number'] == engine]
        for start in range(0, len(engine_df) - window_size + 1, step):
            end = start + window_size
            X.append(engine_df.iloc[start:end, 2:-2].values)
            y.append(engine_df.iloc[end - 1, -1])
    return np.array(X), np.array(y)

window_size = 30
processed_train_data2, processed_train_targets_labels2 = create_time_windows(train_df, window_size, 1)


print("Processed training data shape: ", processed_train_data2.shape)
print("Processed training targets labels shape: ", processed_train_targets_labels2.shape)

# %% [markdown]
# ### Classificatioin of CNN-LSTM Without early stopping

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import tensorflow as tf

# Checkking if GPU is available
if tf.config.list_physical_devices('GPU'):
    device_name = tf.test.gpu_device_name()
    print(f"Using GPU: {device_name}")
else:
    print("No GPU found. Using CPU.")



def create_cnn_lstm_model(input_shape):
    model = Sequential()
    model.add(Conv1D(filters=32, kernel_size=5, activation='relu', input_shape=input_shape))
    model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling1D(pool_size=3))
    model.add(LSTM(50, return_sequences=True, activation='tanh'))
    model.add(Dropout(0.2))
    model.add(LSTM(50, return_sequences=False, activation='tanh'))
    model.add(Dropout(0.2))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    return model

input_shape = (processed_train_data2.shape[1], processed_train_data2.shape[2])
model = create_cnn_lstm_model(input_shape)

model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

model_checkpoint = ModelCheckpoint('best_model_CNN_LSTM.h5', monitor='val_loss')

X_train, X_val, y_train, y_val = train_test_split(processed_train_data2, processed_train_targets_labels2, test_size=0.2, random_state=42)

history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100, batch_size=200, callbacks=[ model_checkpoint])

# %%
import matplotlib.pyplot as plt
def plot_loss_accuracy(history):
    plt.figure(figsize=(14, 5))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Val Loss')
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(loc='upper right')

    plt.subplot(1, 2, 2)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Val Accuracy')
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(loc='upper left')

    plt.show()

plot_loss_accuracy(history)

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc, roc_auc_score
import matplotlib.pyplot as plt
import seaborn as sns

def Evaluating_classification(processed_test_data2,true_rul_labels2):

    y_pred_prob = model.predict(processed_test_data2)
    y_pred = np.where(y_pred_prob > 0.5, 1, 0)

    report = classification_report(true_rul_labels2, y_pred, target_names=['Class 0', 'Class 1'], output_dict=True)
    precision = report['Class 1']['precision']
    recall = report['Class 1']['recall']
    f1_score = report['Class 1']['f1-score']
    accuracy = report['accuracy']

    print(f'Precision: {precision}')
    print(f'Recall: {recall}')
    print(f'F1-Score: {f1_score}')
    print(f'Accuracy: {accuracy}')

    print(classification_report(true_rul_labels2, y_pred, target_names=['Class 0', 'Class 1']))

    conf_matrix = confusion_matrix(true_rul_labels2, y_pred)
    plt.figure(figsize=(10, 7))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Class 0', 'Class 1'], yticklabels=['Class 0', 'Class 1'])
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.title('Confusion Matrix')
    plt.show()

    fpr, tpr, thresholds = roc_curve(true_rul_labels2, y_pred_prob)
    roc_auc = auc(fpr, tpr)

    plt.figure()
    plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic')
    plt.legend(loc='lower right')
    plt.show()

    return precision,recall,f1_score,accuracy

# %%
precision, recall, f1_score, accuracy = Evaluating_classification(processed_test_data2,true_rul_labels2)

# %%
model_performance = pd.DataFrame({
    'Metric': ['Precision', 'Recall', 'F1-Score', 'Accuracy'],
    'Value': [precision, recall, f1_score, accuracy]
})

model_performance_styled = model_performance.style.hide(axis='index').background_gradient(cmap='RdYlBu_r').format({'Value': '{:.4f}'})

model_performance_styled

# %% [markdown]
# For last window

# %%
precision, recall, f1_score, accuracy = Evaluating_classification(processed_test_data_L,true_rul_labels_L)

# %%
model_performance = pd.DataFrame({
    'Metric': ['Precision', 'Recall', 'F1-Score', 'Accuracy'],
    'Value': [precision, recall, f1_score, accuracy]
})

model_performance_styled = model_performance.style.hide(axis='index').background_gradient(cmap='RdYlBu_r').format({'Value': '{:.4f}'})

model_performance_styled

# %% [markdown]
# ### Classifciation CNN-LSTM using Early stopping

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint


def create_cnn_lstm_model(input_shape):
    model = Sequential()
    model.add(Conv1D(filters=32, kernel_size=5, activation='relu', input_shape=input_shape))
    model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling1D(pool_size=3))
    model.add(LSTM(50, return_sequences=True, activation='tanh'))
    model.add(Dropout(0.2))
    model.add(LSTM(50, return_sequences=False, activation='tanh'))
    model.add(Dropout(0.2))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    return model

input_shape = (processed_train_data2.shape[1], processed_train_data2.shape[2])
model = create_cnn_lstm_model(input_shape)

model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])
early_stopping = EarlyStopping(monitor='val_loss', patience=10)

model_checkpoint = ModelCheckpoint('best_model_class1.h5', monitor='val_loss')

X_train, X_val, y_train, y_val = train_test_split(processed_train_data2, processed_train_targets_labels2, test_size=0.2, random_state=42)

history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100, batch_size=200, callbacks=[ early_stopping, model_checkpoint])

# %%
def plot_loss_accuracy(history):
    plt.figure(figsize=(14, 5))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Val Loss')
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(loc='upper right')

    plt.subplot(1, 2, 2)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Val Accuracy')
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(loc='upper left')

    plt.show()

plot_loss_accuracy(history)

# %%
model.summary()

# %%
precision, recall, f1_score, accuracy = Evaluating_classification(processed_test_data2,true_rul_labels2)

# %%
model_performance = pd.DataFrame({
    'Metric': ['Precision', 'Recall', 'F1-Score', 'Accuracy'],
    'Value': [precision, recall, f1_score, accuracy]
})

model_performance_styled = model_performance.style.hide(axis='index').background_gradient(cmap='RdYlBu_r').format({'Value': '{:.4f}'})

model_performance_styled

# %% [markdown]
# For Article setting and whole wiondow

# %%
precision, recall, f1_score, accuracy = Evaluating_classification(processed_test_data_L,true_rul_labels_L)

# %%
model_performance = pd.DataFrame({
    'Metric': ['Precision', 'Recall', 'F1-Score', 'Accuracy'],
    'Value': [precision, recall, f1_score, accuracy]
})

model_performance_styled = model_performance.style.hide(axis='index').background_gradient(cmap='RdYlBu_r').format({'Value': '{:.4f}'})

model_performance_styled

# %% [markdown]
# ### Now we use CNN only for classification

# %% [markdown]
# In this section we deploy early stopping !

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, GlobalAveragePooling1D, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

def create_cnn_model(input_shape):
    model = Sequential()
    model.add(Conv1D(256, 7, activation='relu', input_shape=input_shape))
    model.add(Conv1D(96, 7, activation='relu'))
    model.add(Conv1D(32, 7, activation='relu'))
    model.add(GlobalAveragePooling1D())
    model.add(Dense(64, activation='relu'))
    model.add(Dense(128, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    return model

input_shape = (processed_train_data2.shape[1], processed_train_data2.shape[2])
model = create_cnn_model(input_shape)

model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

early_stopping = EarlyStopping(monitor='val_loss', patience=10)
model_checkpoint = ModelCheckpoint('CNN_model.h5', monitor='val_loss')

X_train, X_val, y_train, y_val = train_test_split(processed_train_data2, processed_train_targets_labels2, test_size=0.2, random_state=42)

history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100, batch_size=200, callbacks=[early_stopping, model_checkpoint])

# %%
import matplotlib.pyplot as plt
def plot_loss_accuracy(history):
    plt.figure(figsize=(14, 5))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Val Loss')
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(loc='upper right')

    plt.subplot(1, 2, 2)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Val Accuracy')
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(loc='upper left')

    plt.show()

plot_loss_accuracy(history)

# %%
model.summary()

# %%
precision, recall, f1_score, accuracy = Evaluating_classification(processed_test_data2,true_rul_labels2)

# %%
model_performance = pd.DataFrame({
    'Metric': ['Precision', 'Recall', 'F1-Score', 'Accuracy'],
    'Value': [precision, recall, f1_score, accuracy]
})

model_performance_styled = model_performance.style.hide(axis='index').background_gradient(cmap='RdYlBu_r').format({'Value': '{:.4f}'})

model_performance_styled

# %% [markdown]
# For all test window

# %%
precision, recall, f1_score, accuracy = Evaluating_classification(processed_test_data_L,true_rul_labels_L)

# %%
model_performance = pd.DataFrame({
    'Metric': ['Precision', 'Recall', 'F1-Score', 'Accuracy'],
    'Value': [precision, recall, f1_score, accuracy]
})

model_performance_styled = model_performance.style.hide(axis='index').background_gradient(cmap='RdYlBu_r').format({'Value': '{:.4f}'})

model_performance_styled

# %% [markdown]
# ### LSTM for Classification
# aslo we deploy early stopping here

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

def create_lstm_model(input_shape):
    model = Sequential()
    model.add(LSTM(128, input_shape=input_shape, return_sequences=True, activation='tanh'))
    model.add(LSTM(64, return_sequences=True, activation='tanh'))
    model.add(Dropout(0.2))
    model.add(LSTM(32, activation='tanh'))
    model.add(Dense(96, activation='relu'))
    model.add(Dense(128, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    return model

input_shape = (processed_train_data2.shape[1], processed_train_data2.shape[2])
model = create_lstm_model(input_shape)

model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

early_stopping = EarlyStopping(monitor='val_loss', patience=10)
model_checkpoint = ModelCheckpoint('best_model_class1.h5', monitor='val_loss')

X_train, X_val, y_train, y_val = train_test_split(processed_train_data2, processed_train_targets_labels2, test_size=0.2, random_state=42)

history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100, batch_size=200, callbacks=[early_stopping, model_checkpoint])

# %%
def plot_loss_accuracy(history):
    plt.figure(figsize=(14, 5))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Val Loss')
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(loc='upper right')

    plt.subplot(1, 2, 2)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Val Accuracy')
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(loc='upper left')

    plt.show()

plot_loss_accuracy(history)

# %%
model.summary()

# %% [markdown]
# Testing on Whole window

# %%
precision, recall, f1_score, accuracy = Evaluating_classification(processed_test_data2,true_rul_labels2)

# %%
model_performance = pd.DataFrame({
    'Metric': ['Precision', 'Recall', 'F1-Score', 'Accuracy'],
    'Value': [precision, recall, f1_score, accuracy]
})

model_performance_styled = model_performance.style.hide(axis='index').background_gradient(cmap='RdYlBu_r').format({'Value': '{:.4f}'})

model_performance_styled

# %% [markdown]
# Testing on Whole window

# %%
precision, recall, f1_score, accuracy = Evaluating_classification(processed_test_data_L,true_rul_labels_L)

# %%
model_performance = pd.DataFrame({
    'Metric': ['Precision', 'Recall', 'F1-Score', 'Accuracy'],
    'Value': [precision, recall, f1_score, accuracy]
})

model_performance_styled = model_performance.style.hide(axis='index').background_gradient(cmap='RdYlBu_r').format({'Value': '{:.4f}'})

model_performance_styled
